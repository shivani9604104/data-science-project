# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani9604104/data-science-project/blob/main/Data_science_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***SHIVANI***

# %% [markdown]
# ## Exploratory Data Analysis
#
# Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# As a business manager, try to find out the weak areas where you can work to make more profit.
#
# What all business problems you can derive by exploring the data?
#
# # **What is Exploratory Data Analysis?**
#
# Exploratory Data Analysis (EDA) is the process of examining and analyzing data sets to summarize their main characteristics, often using visual methods. The goal of EDA is to identify patterns, relationships, and insights that may be hidden in the data and to generate hypotheses for further investigation.
#
# # Some of the key steps in EDA include:
#
# **Data collection**: Gathering data from various sources, such as databases, spreadsheets, or APIs.
#
# **Data cleaning**: Preparing the data for analysis by addressing issues such as missing values, outliers, and inconsistencies.
#
# **Data visualization**: Creating visualizations such as scatter plots, histograms, and box plots to explore the data and identify patterns.
#
# **Data transformation**: Applying mathematical and statistical techniques such as normalization, standardization, and dimensionality reduction to transform the data into a more suitable form for analysis.
#
# **Statistical analysis**: Conducting statistical tests and analyses to test hypotheses, identify correlations, and make predictions.
#
# **Data interpretation**: Interpreting the results of the analyses and drawing conclusions about the data.
#
# Some common tools and libraries used in EDA include Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn, as well as software such as Tableau and Excel.
#
# Overall, EDA is an important step in the data analysis process that can help reveal important insights and guide further analysis.

# %%
#importing nesscary libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df['Ship Mode']
# Out:
# 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship Mode, Length: 9994, dtype: object

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.isna().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df['Ship Mode'].nunique()
# Out:
# 4

# %%
for i in df.columns:
  print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(df)

# %%
fig,axes = plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total Sales VS Quantity ")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Quantity'].agg(sum),x='Sales',y='Quantity',ax=axes[1])
df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()

# %%
fig,axes = plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total profit VS sales ")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Profit'].agg(sum),x='Sales',y='Profit',ax=axes[1])
df.groupby('Sub-Category')['Sales','Profit'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(12,7))
sns.heatmap(df.corr())
plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Sales with different shipping modes and Segments", fontsize=16)
sns.barplot(x=df['Ship Mode'],y=df['Sales'], ax=axes[0,0])
sns.lineplot(x=df['Ship Mode'],y=df['Sales'],ax=axes[0,1])
sns.barplot(x=df['Segment'],y=df['Sales'],ax=axes[1,0])
sns.lineplot(x=df['Segment'],y=df['Sales'],ax=axes[1,1])
plt.show()

# %%
fig,axes = plt.subplots(1,2,figsize=(14,5))
df.groupby('Sub-Category')['Discount','Profit'].agg(sum).plot(kind='bar',ax=axes[0]).set_title('Discount & Profit Relation based on Sub-Category')
df.groupby('Sub-Category')['Profit','Quantity'].agg(sum).plot(kind='bar',ax=axes[1]).set_title('Quantity & Profit Relation based on Sub-Category')
plt.xticks(rotation=90)
plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Distribution plots", fontsize=16)
sns.distplot(df['Sales'],ax=axes[0,0])
sns.distplot(df['Profit'],ax=axes[0,1])
sns.distplot(df['Discount'],ax=axes[1,0])
sns.distplot(df['Quantity'],ax=axes[1,1])
plt.show()

# %%
fig,ax= plt.subplots(1,1,figsize=(12,7))
sns.countplot(x=df['Quantity'],hue=df['Region'])
plt.show()

# %% [markdown]
# # **Significant observations**
# The features Profit and Discounts are highly correlated, indicating that changes in one variable are associated with changes in the other.
#
# Despite a lower quantity of products being sold, the sales were still high, suggesting that customers are willing to pay a premium for these products.
#
# The maximum quantity of products in demand falls within the range of 2-4, indicating that customers tend to purchase products in smaller quantities.
#
# The mode of shipping does not have a significant impact on sales.
#
# Among the three customer segments (Home Office, Corporate, and Consumer), Home Office provides the highest sales, followed by Corporate with only a slight variation.
